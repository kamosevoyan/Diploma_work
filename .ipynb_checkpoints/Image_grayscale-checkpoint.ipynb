# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img_path = "images/bilinear_basis_function.png"

# %%
image = cv2.imread(img_path)

# %%
gray_image = gray = cv2.cvtColor(image[300:-150, 200:-100], cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite(img_path, gray_image)
# Out:
# True

# %%
plt.imshow(image[300:-150, 200:-80])
