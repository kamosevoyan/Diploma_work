# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img_path = "images/unit_cube.png"

# %%
image = cv2.imread(img_path)

# %%
gray_image = gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite(img_path, gray_image[0:-200])
# Out:
# True

# %%
plt.imshow(gray_image[0:-200], cmap="gray")
